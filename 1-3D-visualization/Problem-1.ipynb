# %% [markdown]
# # Problem-1
# Visualize a PDB structure, set styles, and add labels.

# %%
import py3Dmol

# %% [markdown]
# ### TODO-1
# Instantiate py3Dmol viewer with PDB structure 1NCA (Neuraminidase-FAB complex)

# %%
... your code here ...
# Out:
# <div id="3dmolviewer_15253889618372061"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_15253889618372061" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_15253889618372061 = null;
# var warn = document.getElementById("3dmolwarning_15253889618372061");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_15253889618372061 = $3Dmol.createViewer($("#3dmolviewer_15253889618372061"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1NCA", viewer_15253889618372061, {}, function() {
# viewer_15253889618372061.render();
# })
# });
# </script>

# %% [markdown]
# ### TODO-2
# Apply the following styles to this structure:
# * chain N (Neuraminidase): orange cartoon
# * chain H (Heavy chain): blue sphere
# * chain L (Light chain): lightblue sphere

# %%
... your code here ...
# Out:
# <div id="3dmolviewer_1525388961846252"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1525388961846252" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1525388961846252 = null;
# var warn = document.getElementById("3dmolwarning_1525388961846252");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1525388961846252 = $3Dmol.createViewer($("#3dmolviewer_1525388961846252"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1NCA", viewer_1525388961846252, {}, function() {
# 	viewer_1525388961846252.setStyle({"chain": "N"},{"cartoon": {"color": "orange"}});
# 	viewer_1525388961846252.setStyle({"chain": "H"},{"sphere": {"color": "blue"}});
# 	viewer_1525388961846252.setStyle({"chain": "L"},{"sphere": {"color": "lightblue"}});
# viewer_1525388961846252.render();
# })
# });
# </script>

# %% [markdown]
# ### TODO-3: Add text labels to the three chains

# %%
... your code here ...
# Out:
# <div id="3dmolviewer_1525388961855071"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1525388961855071" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1525388961855071 = null;
# var warn = document.getElementById("3dmolwarning_1525388961855071");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1525388961855071 = $3Dmol.createViewer($("#3dmolviewer_1525388961855071"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1NCA", viewer_1525388961855071, {}, function() {
# 	viewer_1525388961855071.setStyle({"chain": "N"},{"cartoon": {"color": "orange"}});
# 	viewer_1525388961855071.setStyle({"chain": "H"},{"sphere": {"color": "blue"}});
# 	viewer_1525388961855071.setStyle({"chain": "L"},{"sphere": {"color": "lightblue"}});
# 	viewer_1525388961855071.addLabel("Neuraminidase",{"fontColor": "orange", "backgroundColor": "lightgray"},{"chain": "N"});
# 	viewer_1525388961855071.addLabel("Heavy chain",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": "H"});
# 	viewer_1525388961855071.addLabel("Light chain",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": "L"});
# viewer_1525388961855071.render();
# })
# });
# </script>

# %% [markdown]
# ### Bonus: Set the style for sugar residues MAN, BMA, and NAG to stick and color by a greenCarbon colorscheme.

# %%
... your code here ...
# Out:
# <div id="3dmolviewer_1525388961862647"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1525388961862647" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab.  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.csb.pitt.edu/build/3Dmol.js');
# }
#
# var viewer_1525388961862647 = null;
# var warn = document.getElementById("3dmolwarning_1525388961862647");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1525388961862647 = $3Dmol.createViewer($("#3dmolviewer_1525388961862647"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1NCA", viewer_1525388961862647, {}, function() {
# 	viewer_1525388961862647.setStyle({"chain": "N"},{"cartoon": {"color": "orange"}});
# 	viewer_1525388961862647.setStyle({"chain": "H"},{"sphere": {"color": "blue"}});
# 	viewer_1525388961862647.setStyle({"chain": "L"},{"sphere": {"color": "lightblue"}});
# 	viewer_1525388961862647.addLabel("Neuraminidase",{"fontColor": "orange", "backgroundColor": "lightgray"},{"chain": "N"});
# 	viewer_1525388961862647.addLabel("Heavy chain",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": "H"});
# 	viewer_1525388961862647.addLabel("Light chain",{"fontColor": "blue", "backgroundColor": "lightgray"},{"chain": "L"});
# 	viewer_1525388961862647.setStyle({"resn": ["MAN", "BMA", "NAG"]},{"stick": {"colorscheme": "greenCarbon"}});
# viewer_1525388961862647.render();
# })
# });
# </script>
